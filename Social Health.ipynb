# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('CodedResponse.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 42 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Gender                               170 non-null    int64
#  1   Age                                  170 non-null    int64
#  2   Accounts                             170 non-null    int64
#  3   MostActive                           170 non-null    object
#  4   FrequencyOfCheckingSM                170 non-null    int64
#  5   TimePerDay                           170 non-null    int64
#  6   HowOftenYouPost                      170 non-null    int64
#  7   WhenYouAccess                        170 non-null    object
#  8   FirstInMorning                       170 non-null    int64
#  9   LastBeforeSleep                      170 non-null    int64
#  10  Purpose                              170 non-null    object
# ...

# %%
pd.set_option('display.max_columns', None)
df.describe()
# Out:
#            Gender         Age    Accounts  FrequencyOfCheckingSM  TimePerDay  \
# count  170.000000  170.000000  170.000000             170.000000  170.000000
# mean     1.429412    3.158824    3.876471               4.164706    3.435294
# std      0.496455    0.655932    1.167625               0.914668    1.282075
# min      1.000000    1.000000    1.000000               2.000000    1.000000
# 25%      1.000000    3.000000    3.000000               3.000000    2.000000
# 50%      1.000000    3.000000    4.000000               4.000000    3.500000
# 75%      2.000000    3.000000    5.000000               5.000000    5.000000
# max      2.000000    5.000000    5.000000               5.000000    5.000000
#
#        HowOftenYouPost  FirstInMorning  LastBeforeSleep  FriendsAndFamily  \
# count       170.000000      170.000000       170.000000        170.000000
# mean          2.688235        1.358824         1.352941          2.194118
# ...

# %%
df.describe(include="object")
# Out:
#                  MostActive     WhenYouAccess  \
# count                   170               170
# unique                   44                18
# top     Instagram, WhatsApp  during free time
# freq                     26                62
#
#                                          Purpose  Medium Types  \
# count                                        170     170   169
# unique                                       102       8    47
# top     keeping in touch with friends and family  Mobile  None
# freq                                          11     113    78
#
#        BullyingandHarassement NegativeComments.1
# count                     170                170
# unique                      6                  6
# top                         5                  3
# freq                       61                 42

# %%
df.describe(exclude="object")
# Out:
#            Gender         Age    Accounts  FrequencyOfCheckingSM  TimePerDay  \
# count  170.000000  170.000000  170.000000             170.000000  170.000000
# mean     1.429412    3.158824    3.876471               4.164706    3.435294
# std      0.496455    0.655932    1.167625               0.914668    1.282075
# min      1.000000    1.000000    1.000000               2.000000    1.000000
# 25%      1.000000    3.000000    3.000000               3.000000    2.000000
# 50%      1.000000    3.000000    4.000000               4.000000    3.500000
# 75%      2.000000    3.000000    5.000000               5.000000    5.000000
# max      2.000000    5.000000    5.000000               5.000000    5.000000
#
#        HowOftenYouPost  FirstInMorning  LastBeforeSleep  FriendsAndFamily  \
# count       170.000000      170.000000       170.000000        170.000000
# mean          2.688235        1.358824         1.352941          2.194118
# ...

# %%
df.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'Gender'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Accounts'}>,
#         <AxesSubplot:title={'center':'FrequencyOfCheckingSM'}>,
#         <AxesSubplot:title={'center':'TimePerDay'}>,
#         <AxesSubplot:title={'center':'HowOftenYouPost'}>],
#        [<AxesSubplot:title={'center':'FirstInMorning'}>,
#         <AxesSubplot:title={'center':'LastBeforeSleep'}>,
#         <AxesSubplot:title={'center':'FriendsAndFamily'}>,
#         <AxesSubplot:title={'center':'Addiction'}>,
#         <AxesSubplot:title={'center':'BulliedorHarassed'}>,
#         <AxesSubplot:title={'center':'BulliedHarassesInCircle'}>],
#        [<AxesSubplot:title={'center':'Anxiety'}>,
#         <AxesSubplot:title={'center':'NoLikesAndComments'}>,
#         <AxesSubplot:title={'center':'NegativeComments'}>,
#         <AxesSubplot:title={'center':'NegativeCommentsInCircle'}>,
# ...

# %%
pd.crosstab(df['Gender'],df['Age'])
# Out:
# Age     1  2   3   4  5
# Gender
# 1       1  1  86   6  3
# 2       3  2  49  12  7

# %%
pd.crosstab(df['Gender'],df['Age'], normalize = 'all')
# Out:
# Age            1         2         3         4         5
# Gender
# 1       0.005882  0.005882  0.505882  0.035294  0.017647
# 2       0.017647  0.011765  0.288235  0.070588  0.041176

# %%
sns.distplot(df['Age'], kde = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age'>

# %%
sns.distplot(df['Gender'], kde = False)
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
df.hist(by='Gender', column='Age', figsize=(10,5))
# Out:
# array([<AxesSubplot:title={'center':'1'}>,
#        <AxesSubplot:title={'center':'2'}>], dtype=object)

# %%
sns.countplot(x="Age",hue="Gender", data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
pd.crosstab(df['Age'],df['Gender'], normalize='all').plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.catplot(x="TimePerDay", y="HoursOfSleep", kind= "swarm", data=df, aspect=2.6)

# %%
sns.catplot(x="Anxiety", y="FrequencyOfCheckingSM", kind= "violin",split=True, data=df)

# %%
sns.catplot(x="MentalHealth", y="TimePerDay", hue = "Age",
           aspect=2.8,
            kind="swarm", data=df)

# %%
sns.catplot(x="PhysicalActivity", y="TimePerDay", hue = "Age",
            col="Gender", aspect=1.45,
            kind="swarm", data=df)

# %%
sns.catplot(x="HoursPhysicalActivity", y="TimePerDay", hue = "Age",
            aspect=2,
            kind="swarm", data=df)

# %%
sns.catplot(x="SleepPatterns", y="TimePerDay", hue = "Age",
            aspect=1.5,
            kind="swarm", data=df)

# %%
pd.crosstab(df['Addiction'],df['FrequencyOfCheckingSM'], normalize='all')
# Out:
# FrequencyOfCheckingSM         2         3         4         5
# Addiction
# 1                      0.000000  0.017647  0.070588  0.200000
# 2                      0.023529  0.170588  0.111765  0.123529
# 3                      0.011765  0.052941  0.064706  0.129412
# 4                      0.000000  0.000000  0.000000  0.023529

# %%
pd.crosstab(df['Age'],df['Gender'], normalize='all').plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.countplot(x="Age",hue="Gender", data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.jointplot(x="Age", y="Gender", data=df, kind="kde")

# %%
pd.pivot_table(df, 'FrequencyOfCheckingSM', index=['Age', 'Gender'],
              columns=['TimePerDay'],aggfunc=np.mean)
# Out:
# TimePerDay         1         2         3         4         5
# Age Gender
# 1   1            NaN       NaN       NaN       NaN  5.000000
#     2            NaN  3.000000       NaN  5.000000  5.000000
# 2   1            NaN       NaN  4.000000       NaN       NaN
#     2            NaN       NaN  3.000000  3.000000       NaN
# 3   1       3.428571  3.461538  4.315789  4.600000  4.789474
#     2            NaN  3.000000  3.545455  4.500000  4.789474
# 4   1       2.500000  4.000000  3.333333       NaN       NaN
#     2       2.000000  4.000000       NaN  4.333333  5.000000
# 5   1       3.000000  3.500000       NaN       NaN       NaN
#     2            NaN  4.000000  4.000000  5.000000  5.000000

# %%
sns.pairplot(df, diag_kind='kde')

# %%
corr = df.corr()
corr
# Out:
#                                        Gender       Age  Accounts  \
# Gender                               1.000000  0.116400 -0.010028
# Age                                  0.116400  1.000000 -0.105573
# Accounts                            -0.010028 -0.105573  1.000000
# FrequencyOfCheckingSM                0.130001 -0.053722  0.312808
# TimePerDay                           0.336753 -0.138986  0.368161
# HowOftenYouPost                      0.188970  0.198464  0.115700
# FirstInMorning                      -0.203014 -0.012906 -0.236647
# LastBeforeSleep                     -0.118486 -0.047607 -0.281122
# FriendsAndFamily                     0.095729 -0.224330 -0.046390
# Addiction                           -0.063657 -0.039060 -0.041843
# BulliedorHarassed                   -0.159072  0.000661  0.068934
# BulliedHarassesInCircle             -0.140089 -0.001355 -0.114419
# Anxiety                             -0.006851  0.000592 -0.012949
# ...

# %%
sns.heatmap(corr, annot=False)
# Out:
# <AxesSubplot:>

# %%
df.hist(by='Gender', column='Age', figsize=(10,5))
# Out:
# array([<AxesSubplot:title={'center':'1'}>,
#        <AxesSubplot:title={'center':'2'}>], dtype=object)

# %%
import seaborn as sns

# %%
sns.distplot(df['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
# look if Instagram was selected
condition = df['MostActive'].str.contains('Instagram')

# if it is selected what we want the cell to be
if_condition = 1

# if it is not selected what we want the cell to be
if_not_condition = 0

# Create a new column for Instagram where 1 means Instagram was selected, and 0 means it was not
df['Instagram'] = np.where(condition, if_condition, if_not_condition)

df
# Out:
#      Gender  Age  Accounts                                         MostActive  \
# 0         1    3         5           Instagram, WhatsApp, LinkedIn, Pinterest
# 1         2    4         5  Facebook, Instagram, WhatsApp, LinkedIn, Snapchat
# 2         1    3         4            Facebook, Instagram, WhatsApp, LinkedIn
# 3         1    4         5  Facebook, Instagram, WhatsApp, Twitter, Linked...
# 4         2    3         5                                           WhatsApp
# ..      ...  ...       ...                                                ...
# 165       1    3         5                                           WhatsApp
# 166       2    3         4             Facebook, Instagram, WhatsApp, Twitter
# 167       1    3         5            Facebook, Instagram, WhatsApp, LinkedIn
# 168       1    3         4            Facebook, Instagram, WhatsApp, LinkedIn
# 169       2    3         4                     Instagram, WhatsApp, Pinterest
#
# ...

# %%
df.head()
# Out:
#    Gender  Age  Accounts                                         MostActive  \
# 0       1    3         5           Instagram, WhatsApp, LinkedIn, Pinterest
# 1       2    4         5  Facebook, Instagram, WhatsApp, LinkedIn, Snapchat
# 2       1    3         4            Facebook, Instagram, WhatsApp, LinkedIn
# 3       1    4         5  Facebook, Instagram, WhatsApp, Twitter, Linked...
# 4       2    3         5                                           WhatsApp
#
#    FrequencyOfCheckingSM  TimePerDay  HowOftenYouPost  \
# 0                      5           5                6
# 1                      5           5                3
# 2                      5           5                6
# 3                      4           3                2
# 4                      5           5                2
#
#                                        WhenYouAccess  FirstInMorning  \
# 0                                   any spare moment               1
# ...
